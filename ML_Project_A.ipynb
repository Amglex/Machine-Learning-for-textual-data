# %% [markdown]
# # Machine Learning for Textual Data - The Bible and other religious texts
# <b> Advanced Numberical Methods and Data Analysis - University of St. Gallen (HSG) - Spring semester 2019 </b>
#
# Elisa Fleissner       (14-350-608)
#
# Lars Stauffenegger    (tbd)
#
# Alexander Steeb       (17-614-611)
#
# 05.05.2019
#
# --------------------------------------------------------------------------------------------

# %% [markdown]
# ## Project plan and structure
#
# In this project we analyse the bible text and other religious texts using machine learning for textual data. From this analysis we expect to see different relevant topics and contexts between the books of the bible and between the different religious texts.
#
# This analysis is structures as follows: In a first step, a thorough analysis of the bible is done to understand different topics within the books and to see a development of the topics over time. We expect to see that certain topics where clearly more relevant in the old testament and the new testament. For the topic analysis in this section, we will use the Latent Dirichlet Allocation (LDA) and the Word2Vec algorithm is used to understand the context of certain words. This allows to capture differences in the perception of one specific word in the old. vs new testament.
# In a second part we will then include other religious texts such as the Qu'aran and others. We will perform an anlysis over **five** texts to find similarities and patterns ...
#
# ### PART I: The Bible ###
# - Before starting with the analysis and data import, we need to first setup helpers function and import all relevant libraries used for this project.
# - Then we are importing the data and assigning the correct names of the books to the texts as well as the testament (old or new).
# - We then have to process the data to make it suitable for the machine learning algorithm. We achieve this by defining several formulas including preprocessing, stopword removal, tokenization, lemmatization and stemming.
# - When the data is ready, the actual analysis can be performed
#
# ### PART II: 5 religious texts ###
# - The imported functions and cleaning steps can be used from PART I, however, we need to import all texts and bring them to the same format (i.e. no separation between the different books)
# - Cleaning of the data using the functions from PART I
# - Analysis

# %% [markdown]
# ## 0. Setup

# %%
# import functions
import json
import os
import shutil
import sys
import requests, 
import zipfile
import io
import re

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns

from textblob import TextBlob, Word
import nltk
from nltk.corpus import stopwords
from wordcloud import WordCloud

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

import word2vec

# %%
# Option to display whole text and not only first few words
pd.set_option('display.max_colwidth', 1)

# %%
print(sys.executable)
print(sys.version)

# %% [markdown]
# # PART I: The Bible

# %% [markdown]
# ## Preparation
# ### TextBlob
# It is important to install textblob correctly and to download the corpora. Source: https://textblob.readthedocs.io/en/dev/
#
#
# ```
# pip install -U textblob
# python -m textblob.download_corpora
# ```

# %% [markdown]
# ### Helper functions

# %%
# Remove existing folder
# based on: https://stackoverflow.com/questions/303200/how-do-i-remove-delete-a-folder-that-is-not-empty-with-python
def remove_folder(path):
    # check if folder exists
    if os.path.exists(path):
         # remove if exists
         shutil.rmtree(path)
    else:
         # throw your exception to handle this special scenario
         print('Folder does not exist')

# Get one text string instead of separated text bits
def gen_full_text(texts):
    full_text = ''
    for text in texts:
        full_text += text
    return(full_text)

# Helper function to get the digits in one text
def get_num(text):
    return(int(''.join([n for n in text if n.isdigit()])))

# Stopwords
custom_stopwords = stopwords.words('english')
custom_stopwords.extend(["nephi","alma","mormoni","ether", "say", "let", "may", "give", 
                         "make", "come", "go", "take", "put", "an", "er"])

# %% [markdown]
# ## 1. Data import

# %% [markdown]
# In this section we will import the bible data. Particular caution has to be paid to the correct specification of the different books and the old/new testamnet as this is crucial for the following LDA analysis.
#
# Data source: https://sites.google.com/site/ruwach/bibletext

# %%
remove_folder("data")

# %%
old_zip_file_url = "https://sites.google.com/site/ruwach/Basic_English_OldTestament.zip?attredirects=0"
#old_zip_file_url = "http://ruwach.googlepages.com/OldTestament.zip"

new_zip_file_url = "https://sites.google.com/site/ruwach/Basic_English_NewTestament.zip?attredirects=0"
#new_zip_file_url = "http://ruwach.googlepages.com/NewTestament.zip"
    
def unzip(url):
    r = requests.get(url)
    z = zipfile.ZipFile(io.BytesIO(r.content))
    z.extractall("data/")
    
unzip(old_zip_file_url)
unzip(new_zip_file_url)

# %%
path = "data"
df = pd.DataFrame()  

testaments = os.listdir(path)

for testament in testaments:
    testament_path = os.path.join(path,testament)
    books = os.listdir(testament_path)
    
    for book in books:
        book_path = os.path.join(testament_path,book)
        files = os.listdir(book_path)    
            
        for file in files:
            file_path = os.path.join(book_path,file) 
            
            with open(file_path, "r", encoding = "utf-8") as infile:
                text = infile.read()
                df = df.append([[text, testament, book, file, file_path]], ignore_index=True)
                
df.columns = ["text", "testament", "book", "file", "path"]

# %%
books = (
    "Genesis",
    "Exodus",
    "Leviticus",
    "Numbers",
    "Deuteronomy",
    "Joshua",
    "Judges",
    "Ruth",
    "1 Samuel",
    "2 Samuel",
    "1 Kings",
    "2 Kings",
    "1 Chronicles",
    "2 Chronicles",
    "Ezra",
    "Nehemiah",
    "Esther",
    "Job",
    "Psalms",
    "Proverbs",
    "Ecclesiastes",
    "Song of Solomon",
    "Isaiah",
    "Jeremiah",
    "Lamentations",
    "Ezekiel",
    "Daniel",
    "Hosea",
    "Joel",
    "Amos",
    "Obadiah",
    "Jonah",
    "Micah",
    "Nahum",
    "Habbakuk",
    "Zephaniah",
    "Haggai",
    "Zechariah",
    "Malachi",
    "Matthew",
    "Mark",
    "Luke",
    "John",
    "Acts",
    "Romans",
    "1 Corinthians",
    "2 Corinthians",
    "Galatians",
    "Ephesians",
    "Philippians",
    "Colossians",
    "1 Thessalonians",
    "2 Thessalonians",
    "1 Timothy",
    "2 Timothy",
    "Titus",
    "Philemon",
    "Hebrews",
    "James",
    "1-2 Peter",
    "1-3 John",
    "Jude",
    "Revalation")

# %%
# Order the books
books_order = pd.DataFrame.from_records(zip(books, range(1,len(books))))
books_order.columns = ["book", "order"]

# Merge the book information to the downloaded text
df = pd.merge(df,books_order, on ='book')

# %%
# Get the number out of the file name to sort the texts correctly
df['file'] = df['file'].apply(get_num)
df = df.sort_values(["order", "file"], ascending = [True, True])
df.reset_index(drop = True, inplace = True)

# %% [markdown]
# ## 2. Data cleaning

# %% [markdown]
# In this section we will prepare the data to be analysed. We therefore need to apply different techniques to clean the data so that machine learning algorithms can analyse the data set. For a first inspection of the data, we will use a wordcloud and word count analysis.
#
# The following steps are part of the preprocessing phase to make the text ready for the algorithms (https://medium.com/@bedigunjit/simple-guide-to-text-classification-nlp-using-svm-and-naive-bayes-with-python-421db3a72d34)
#
# **Tools:**
# 1. Preprocessor
#     - Only keep latin characters
#     - Remove roman numerals
#     - Change all the text to lower case
#     - Remove line breaks
# 2. Lemmatizer
#     - Based on PoS tags
# 3. Remove Stop words
# 4. Wordcloud text processor

# %%
def preprocessor(t):
    '''
    Takes a str as an input and applies various preproccesing steps.
    Returns a str.
    '''
    # Regex to remove roman numerals / source: https://stackoverflow.com/questions/267399/how-do-you-match-only-valid-roman-numerals-with-a-regular-expression
    t = re.sub(r'(?=\b[MCDXLVI]{1,6}\b)M{0,4}(?:CM|CD|D?C{0,3})(?:XC|XL|L?X{0,3})(?:IX|IV|V?I{0,3})', ' ', t)
    t = t.lower() 
    t = t.replace('\n', ' ') # Replace newline with space
    t = re.sub('[!?;]',' . ',t)
    t = re.sub('[^a-zA-Z .]',' ',t)
    return(t.strip())


# inspired by https://www.machinelearningplus.com/nlp/lemmatization-examples-python/
def lemmatizer(text):
    """
    Takes a str as an input and lemmatization based on PoS tagging 
    Returns a str
    """
    text = TextBlob(text)
    tag_dict = {"J": 'a', 
                "N": 'n', 
                "V": 'v', 
                "R": 'r'}

    result = ' '
    for sentence in text.sentences:
        words_and_tags = [(w, tag_dict.get(pos[0], 'n')) for w, pos in sentence.tags()]
        lemmatized_list = [w.lemmatize(tag) for w, tag in words_and_tags]
        sentence_new = ' '.join(lemmatized_list)
        result += sentence_new + ' . '
    return(result)

def remove_stopwords(text):
    """
    Takes a str as an input and removes all stopwords based on a "custom_stopwords" list
    Returns a str
    """
    text = TextBlob(text)
    text = (token for token in text.tokens if token not in custom_stopwords)
    stopremoved = ' '.join(text)
    return(str(stopremoved))

def wordcloud_map(text_corp):
    """"
    Takes one column of a Pandas Dataframe with strings as an input
    Concatonates these strings and generates a wordcloud
    Returns the wordcloud 
    """
    full_text = ''
    for text in text_corp:
        full_text += text          
    wordcloud = WordCloud(max_font_size = 40,background_color = "white").generate(full_text)

    plt.figure(figsize = (10,10))
    plt.imshow(wordcloud, interpolation = "bilinear")
    plt.axis("off")
    plt.show()

# %%
# Out:
# Object `sentence.tags` not found.

# %%
# %%time
df['clean'] = df['text']
df['clean'] = df['clean'].apply(preprocessor)
df['clean'] = df['clean'].apply(lemmatizer)
# Out:
# CPU times: user 41 s, sys: 520 ms, total: 41.5 s
# Wall time: 41.7 s

# %%
# %%time
df['clean_rm'] = df['clean'].apply(remove_stopwords)
# Out:
# CPU times: user 6.47 s, sys: 37.2 ms, total: 6.5 s
# Wall time: 6.53 s

# %% [markdown]
# ## 3. Data inspection
# In this section we will conduct some simple analysis of the processed data to better understand the most frequent words. We will use a wordcloud ...
#
# ### Wordcloud
#
# The wordcloud is used to display the frequency of the words by size. This is a suitable tool for to get a first glimpse of the texts to be analysed.
#
# We conduct this analysis for
# - the entire bible
# - the old testament
# - the new testament

# %%
# Entire bible
wordcloud_map(df['clean_rm'])

# Old testament only
i = 0
print(testaments[i])

data = df.loc[df.testament == testaments[i],'clean_rm']
wordcloud_map(data)

# New testament only
i = 1
print(testaments[i])

data = df.loc[df.testament == testaments[i],'clean_rm']
wordcloud_map(data)
# Out:
# Old Testament
# New Testament

# %% [markdown]
# ### Term frequency
# In this analysis we will compare the word frequency of the entire bible to the old and new testament.

# %%
# We define a function for the word count and plotting
def word_count(text):
    full_text = ''
    for words in text:
        full_text += words
    
    # Split the string into words
    words = full_text.split()

    # Define minimum length
    len([words for words in words if len(words) > 5])

    # Calculate and plot the word frequency
    fd = nltk.FreqDist(words)
    fd.plot(30, cumulative = False)

# %%
# Calling the function and plotting the results
print("Entire bible")  
text = df["clean_rm"]
word_count(text)

print("Old testament")
text = df.loc[df.testament == "Old Testament", "clean_rm"]
word_count(text)

print("New testament")
text = df.loc[df.testament == "New Testament", "clean_rm"]
word_count(text)
# Out:
# Entire bible
# Old testament
# New testament

# %% [markdown]
# ## 4. Model 1 - LDA

# %% [markdown]
# ### Description of the model
# Latent Dirichlet Allocation (LDA) is a method to identify topics within a text corpus. This model has been developed by [Blei, Ng and Jordan (2003)](http://www.jmlr.org/papers/volume3/blei03a/blei03a.pdf) and is based on a three-level hierarchical Bayesian model and the Dirichlet distribution.
# We will use this method for a preliminary analysis on our bible texts to see whether the topics discussed in the books have been changing over time. We expect to see that over the time (over the evolvement of the different books), the topics have changed significantly. An interesting change will probably also be observed for the beginning of the new testament.
# We got inspiration for this code from Knoepfl, Rieger & Sommer (2018).

# %% [markdown]
# ### Estimation 1: Topic identification and wordcloud representation
# In this step, the LDA model is used to identify the different topics and output the words around each topic as a wordcloud.

# %%
# Choose the hyper parameter "number of topics"
n_components = 3

# %%
# Get the text
text = df['clean_rm']

# Vectorize the text
count = CountVectorizer(
            min_df = 2,
            max_df = 0.90,
            ngram_range = (1,3)
            )

txt_count = count.fit_transform(text)
txt_count
# Out:
# <1136x60964 sparse matrix of type '<class 'numpy.int64'>'
# 	with 352567 stored elements in Compressed Sparse Row format>

# %%
# Fit LDA model
lda = LatentDirichletAllocation(
    n_components = n_components, 
    random_state = 123, 
    learning_method = 'batch',
    max_iter = 50,
    verbose = True,
    evaluate_every = True)

X_topics = lda.fit_transform(txt_count)
lda.components_.shape
# Out:
# iteration: 1 of max_iter: 50, perplexity: 11332.9079
# iteration: 2 of max_iter: 50, perplexity: 9735.6698
# iteration: 3 of max_iter: 50, perplexity: 9437.5026
# iteration: 4 of max_iter: 50, perplexity: 9260.1500
# iteration: 5 of max_iter: 50, perplexity: 9137.6981
# iteration: 6 of max_iter: 50, perplexity: 9048.2971
# iteration: 7 of max_iter: 50, perplexity: 8977.4664
# iteration: 8 of max_iter: 50, perplexity: 8916.1548
# iteration: 9 of max_iter: 50, perplexity: 8871.8576
# iteration: 10 of max_iter: 50, perplexity: 8837.6091
# iteration: 11 of max_iter: 50, perplexity: 8810.0154
# iteration: 12 of max_iter: 50, perplexity: 8786.9386
# iteration: 13 of max_iter: 50, perplexity: 8767.5526
# iteration: 14 of max_iter: 50, perplexity: 8747.9658
# iteration: 15 of max_iter: 50, perplexity: 8726.4574
# iteration: 16 of max_iter: 50, perplexity: 8710.9491
# iteration: 17 of max_iter: 50, perplexity: 8701.3810
# iteration: 18 of max_iter: 50, perplexity: 8695.8634
# iteration: 19 of max_iter: 50, perplexity: 8690.5684
# iteration: 20 of max_iter: 50, perplexity: 8684.4015
# iteration: 21 of max_iter: 50, perplexity: 8674.9213
# iteration: 22 of max_iter: 50, perplexity: 8660.8860
# iteration: 23 of max_iter: 50, perplexity: 8655.7283
# iteration: 24 of max_iter: 50, perplexity: 8652.0819
# iteration: 25 of max_iter: 50, perplexity: 8648.8243
# iteration: 26 of max_iter: 50, perplexity: 8645.7817
# iteration: 27 of max_iter: 50, perplexity: 8642.8626
# iteration: 28 of max_iter: 50, perplexity: 8640.2086
# iteration: 29 of max_iter: 50, perplexity: 8637.7913
# iteration: 30 of max_iter: 50, perplexity: 8635.8755
# iteration: 31 of max_iter: 50, perplexity: 8634.4624
# iteration: 32 of max_iter: 50, perplexity: 8633.1536
# iteration: 33 of max_iter: 50, perplexity: 8631.9499
# iteration: 34 of max_iter: 50, perplexity: 8630.7291
# iteration: 35 of max_iter: 50, perplexity: 8629.4440
# iteration: 36 of max_iter: 50, perplexity: 8628.2390
# iteration: 37 of max_iter: 50, perplexity: 8627.1342
# iteration: 38 of max_iter: 50, perplexity: 8625.8507
# iteration: 39 of max_iter: 50, perplexity: 8623.0650
# iteration: 40 of max_iter: 50, perplexity: 8615.9663
# iteration: 41 of max_iter: 50, perplexity: 8611.6389
# iteration: 42 of max_iter: 50, perplexity: 8610.5581
# iteration: 43 of max_iter: 50, perplexity: 8609.5068
# iteration: 44 of max_iter: 50, perplexity: 8608.3971
# iteration: 45 of max_iter: 50, perplexity: 8606.9801
# iteration: 46 of max_iter: 50, perplexity: 8604.6992
# iteration: 47 of max_iter: 50, perplexity: 8602.5667
# iteration: 48 of max_iter: 50, perplexity: 8601.3839
# iteration: 49 of max_iter: 50, perplexity: 8600.1438
# iteration: 50 of max_iter: 50, perplexity: 8598.4895
# (3, 60964)

# %%
# Print most important words of every topic
print("Most important words per topic:")
n_top_words = 10

feature_names = count.get_feature_names()

for topic_idx, topic in enumerate(lda.components_):
    print()
    print("Topic {}:".format(topic_idx))
    
    
    print(" ".join([feature_names[i] for i in topic.argsort() [:-n_top_words - 1:-1]]))
# Out:
# Most important words per topic:
#
# Topic 0:
# god lord man see one evil word thing keep jesus
#
# Topic 1:
# lord king son god israel land people place send men
#
# Topic 2:
# lord son offering child moses one priest holy house israel

# %% [markdown]
# ### Estimation 2: Evolvement over time
# In this step we will plot the different topics identified in step 1 over the development of the bible (the books).

# %%
X_topics = pd.DataFrame(X_topics)

X_topics['order'] = df['order']

X_topics_mean = X_topics.groupby(df['book']).mean()

X_topics_mean = X_topics_mean.sort_values('order', )
df.reset_index(drop=True, inplace=True)

X_topics_mean =X_topics_mean.iloc[:,0:n_components]

# %%
X_topics_mean.plot(kind='bar',
                   stacked=True,
                   rot='vertical',
                   ylim=(0,1),
                   figsize=(15, 5), 
                   legend=True, 
                   fontsize=12,
                   colormap = "viridis"
                  )

# %% [markdown]
# ## 5. Model 2 - Word2vec

# %% [markdown]
# As a second model we would like to present the Word2vec model, which allows for contextual analysis. The model has been introduced by [Mikolov et al.](https://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). The word2vec method allows to reconstruct linguistic features of the corpus analysed and embedds the words in their context using a shallow two-layer network. This method allows to evaluate the associations to a certain word and thus allows to capture the sentiment of the text. Inspiration for this part has been obtained [here](https://nbviewer.jupyter.org/github/danielfrg/word2vec/blob/master/examples/word2vec.ipynb).
#
# Using this method, we can detect different word associations within the different parts of the bible. We expect for example, that the word *"god"* could be embedded differently in the old than in the new testament.

# %% [markdown]
# **TODO**
#
# - z.B. was wird mit Gott im alten vs neune Testament verbunden etc. / Gott steht zu Jesus im Verhältnis wie ....
# - Visualization of results

# %% [markdown]
# ### Model estimation

# %%
import gensim

# %%
sentences = [['first', 'sentence'], ['second', 'sentence']]
# train word2vec on the two sentences
model = gensim.models.Word2Vec(sentences, min_count=1)

# %%
full_text = gen_full_text(df['clean'])

full_text = TextBlob(full_text)

full_text = [[word.split().raw] for word in full_text.sentences]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-168-e7788730766f> in <module>
#       3 full_text = TextBlob(full_text)
#       4
# ----> 5 full_text = [[word.split().raw] for word in full_text.sentences]
#
# <ipython-input-168-e7788730766f> in <listcomp>(.0)
#       3 full_text = TextBlob(full_text)
#       4
# ----> 5 full_text = [[word.split().raw] for word in full_text.sentences]
#
# AttributeError: 'WordList' object has no attribute 'raw'

# %%
full_text.noun_phrases
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-176-1a61aed45743> in <module>
# ----> 1 full_text.noun_phrases
#
# ~/.virtualenvs/ML/lib/python3.7/site-packages/textblob/decorators.py in __get__(self, obj, cls)
#      22         if obj is None:
#      23             return self
# ---> 24         value = obj.__dict__[self.func.__name__] = self.func(obj)
#      25         return value
#      26
#
# ~/.virtualenvs/ML/lib/python3.7/site-packages/textblob/blob.py in noun_phrases(self)
#     466         """Returns a list of noun phrases for this blob."""
#     467         return WordList([phrase.strip().lower()
# --> 468                         for phrase in self.np_extractor.extract(self.raw)
#     469                         if len(phrase) > 1])
#     470
#
# ~/.virtualenvs/ML/lib/python3.7/site-packages/textblob/en/np_extractors.py in extract(self, sentence)
#     146                 t1 = tags[x]
#     147                 t2 = tags[x + 1]
# --> 148                 key = t1[1], t2[1]
#     149                 value = self.CFG.get(key, '')
#     150                 if value:
#
# KeyboardInterrupt:

# %%
model = gensim.models.Word2Vec(full_text, 
                               min_count=1,
                               size = 100, # size of NN layers
                              )

# %%
full_text
# Out:
# [["['at', 'the', 'first', 'god', 'make', 'the', 'heaven', 'and', 'the', 'earth', '.']"],
#  ["['and', 'the', 'earth', 'be', 'waste', 'and', 'without', 'form', 'and', 'it', 'be', 'dark', 'on', 'the', 'face', 'of', 'the', 'deep', 'and', 'the', 'spirit', 'of', 'god', 'be', 'move', 'on', 'the', 'face', 'of', 'the', 'water', '.']"],
#  ["['and', 'god', 'say', 'let', 'there', 'be', 'light', 'and', 'there', 'be', 'light', '.']"],
#  ["['and', 'god', 'look', 'on', 'the', 'light', 'saw', 'that', 'it', 'be', 'good', 'and', 'god', 'make', 'a', 'division', 'between', 'the', 'light', 'and', 'the', 'dark', 'name', 'the', 'light', 'day', 'and', 'the', 'dark', 'night', '.']"],
#  ["['and', 'there', 'be', 'even', 'and', 'there', 'be', 'morning', 'the', 'first', 'day', '.']"],
#  ["['then', 'she', 'get', 'up', 'and', 'go', 'away', 'and', 'take', 'off', 'her', 'veil', 'and', 'put', 'on', 'her', 'widow', 's', 'clothing', '.']"],
#  ["['then', 'judah', 'send', 'his', 'friend', 'hirah', 'with', 'the', 'young', 'goat', 'to', 'get', 'back', 'the', 'thing', 'which', 'he', 'have', 'give', 'a', 'a', 'sign', 'to', 'the', 'woman', 'but', 'she', 'be', 'not', 'there', '.']"],
#  ["['and', 'he', 'put', 'question', 'to', 'the', 'men', 'of', 'the', 'place', 'say', 'where', 'be', 'the', 'loose', 'woman', 'who', 'be', 'in', 'enaim', 'by', 'the', 'wayside', 'and', 'they', 'say', 'there', 'be', 'no', 'such', 'woman', 'there', '.']"],
#  ["['so', 'he', 'go', 'back', 'to', 'judah', 'and', 'say', 'have', 'not', 'see', 'her', 'and', 'the', 'men', 'of', 'the', 'place', 'say', 'that', 'there', 'be', 'no', 'such', 'woman', 'there', '.']"],
#  ["['and', 'judah', 'say', 'let', 'her', 'keep', 'the', 'thing', 'so', 'that', 'we', 'may', 'not', 'be', 'sham', 'send', 'the', 'young', 'goat', 'but', 'you', 'do', 'not', 'see', 'the', 'woman', '.']"],
#  ["['now', 'about', 'three', 'month', 'after', 'this', 'word', 'come', 'to', 'judah', 'that', 'tamar', 'his', 'daughter', 'in', 'law', 'have', 'be', 'act', 'like', 'a', 'loose', 'woman', 'and', 'be', 'with', 'child', '.']"],
#  ["['and', 'judah', 'say', 'take', 'her', 'out', 'and', 'let', 'her', 'be', 'burn', '.']"],
#  ["['and', 'while', 'she', 'be', 'be', 'take', 'out', 'she', 'send', 'word', 'to', 'her', 'father', 'in', 'law', 'say', 'the', 'man', 'whose', 'property', 'these', 'thing', 'be', 'be', 'the', 'father', 'of', 'my', 'child', 'say', 'then', 'whose', 'be', 'this', 'ring', 'and', 'this', 'cord', 'and', 'this', 'stick', 'then', 'judah', 'say', 'openly', 'that', 'they', 'be', 'his', 'and', 'say', 'she', 'be', 'more', 'upright', 'than', 'be', 'for', 'do', 'not', 'give', 'her', 'to', 'shelah', 'my', 'son', '.']"],
#  ["['and', 'he', 'have', 'no', 'more', 'connection', 'with', 'her', '.']"],
#  ["['and', 'when', 'the', 'time', 'come', 'for', 'her', 'to', 'give', 'birth', 'it', 'be', 'clear', 'that', 'there', 'be', 'two', 'child', 'in', 'her', 'body', '.']"],
#  ["['and', 'while', 'she', 'be', 'in', 'the', 'act', 'of', 'give', 'birth', 'one', 'of', 'them', 'put', 'out', 'his', 'hand', 'and', 'the', 'woman', 'who', 'be', 'with', 'her', 'put', 'a', 'red', 'thread', 'round', 'his', 'hand', 'say', 'this', 'one', 'come', 'out', 'first', '.']"],
#  ["['but', 'then', 'he', 'take', 'his', 'hand', 'back', 'again', 'and', 'his', 'brother', 'come', 'first', 'to', 'birth', 'and', 'the', 'woman', 'say', 'what', 'an', 'opening', 'you', 'have', 'make', 'for', 'yourself', 'so', 'he', 'be', 'name', 'perez', '.']"],
#  ["['and', 'then', 'his', 'brother', 'come', 'out', 'with', 'the', 'red', 'thread', 'round', 'his', 'hand', 'and', 'he', 'be', 'name', 'zerah', '.']"],
#  ["['now', 'joseph', 'be', 'take', 'down', 'to', 'egypt', 'and', 'potiphar', 'the', 'egyptian', 'a', 'captain', 'of', 'high', 'position', 'in', 'pharaoh', 's', 'house', 'get', 'him', 'for', 'a', 'price', 'from', 'the', 'ishmaelites', 'who', 'have', 'take', 'him', 'there', '.']"],
#  ["['and', 'the', 'lord', 'be', 'with', 'joseph', 'and', 'he', 'do', 'well', 'and', 'he', 'be', 'live', 'in', 'the', 'house', 'of', 'his', 'master', 'the', 'egyptian', '.']"],
#  ["['and', 'his', 'master', 'saw', 'that', 'the', 'lord', 'be', 'with', 'him', 'make', 'everything', 'he', 'do', 'go', 'well', '.']"],
#  ["['and', 'have', 'a', 'high', 'opinion', 'of', 'joseph', 'a', 'his', 'servant', 'he', 'make', 'him', 'the', 'overseer', 'of', 'his', 'house', 'and', 'give', 'him', 'control', 'over', 'all', 'he', 'have', '.']"],
#  ["['and', 'from', 'the', 'time', 'when', 'he', 'make', 'him', 'overseer', 'and', 'give', 'him', 'control', 'of', 'all', 'his', 'property', 'the', 'blessing', 'of', 'the', 'lord', 'be', 'with', 'the', 'egyptian', 'because', 'of', 'joseph', 'the', 'blessing', 'of', 'the', 'lord', 'be', 'on', 'all', 'he', 'have', 'in', 'the', 'house', 'and', 'in', 'the', 'field', '.']"],
#  ["['and', 'he', 'give', 'joseph', 'control', 'of', 'all', 'his', 'property', 'keep', 'no', 'account', 'of', 'anything', 'but', 'only', 'the', 'food', 'which', 'be', 'put', 'before', 'him', '.']"],
#  ["['now', 'joseph', 'be', 'very', 'beautiful', 'in', 'form', 'and', 'face', '.']"],
#  ["['and', 'after', 'a', 'time', 'his', 'master', 's', 'wife', 'look', 'on', 'joseph', 'with', 'desire', 'say', 'to', 'him', 'be', 'my', 'lover', '.']"],
#  ["['but', 'he', 'would', 'not', 'and', 'say', 'to', 'her', 'you', 'see', 'that', 'my', 'master', 'keep', 'no', 'account', 'of', 'what', 'do', 'in', 'his', 'house', 'and', 'have', 'put', 'all', 'his', 'property', 'in', 'my', 'control', 'so', 'that', 'no', 'one', 'have', 'more', 'authority', 'in', 'this', 'house', 'than', 'have', 'he', 'have', 'keep', 'nothing', 'back', 'from', 'me', 'but', 'you', 'because', 'you', 'be', 'his', 'wife', 'how', 'then', 'may', 'do', 'this', 'great', 'wrong', 'sin', 'against', 'god', 'and', 'day', 'after', 'day', 'she', 'go', 'on', 'request', 'joseph', 'to', 'come', 'to', 'her', 'and', 'be', 'her', 'lover', 'but', 'he', 'would', 'not', 'give', 'ear', 'to', 'her', '.']"],
#  ["['now', 'one', 'day', 'he', 'go', 'into', 'the', 'house', 'to', 'do', 'his', 'work', 'and', 'not', 'one', 'of', 'the', 'men', 'of', 'the', 'house', 'be', 'inside', '.']"],
#  ["['and', 'pull', 'at', 'his', 'coat', 'she', 'say', 'come', 'to', 'my', 'bed', 'but', 'slip', 'out', 'of', 'his', 'coat', 'he', 'go', 'run', 'away', '.']"],
#  ["['and', 'when', 'she', 'saw', 'that', 'he', 'have', 'get', 'away', 'let', 'her', 'keep', 'his', 'coat', 'she', 'send', 'for', 'the', 'men', 'of', 'her', 'house', 'and', 'say', 'to', 'them', 'see', 'he', 'have', 'let', 'a', 'hebrew', 'come', 'here', 'and', 'make', 'sport', 'of', 'u', 'he', 'come', 'to', 'my', 'bed', 'and', 'give', 'a', 'loud', 'cry', 'and', 'hearing', 'it', 'he', 'go', 'run', 'out', 'without', 'his', 'coat', '.']"],
#  ["['and', 'she', 'keep', 'his', 'coat', 'by', 'her', 'till', 'his', 'master', 'come', 'back', '.']"],
#  ["['then', 'she', 'give', 'him', 'the', 'same', 'story', 'say', 'the', 'hebrew', 'servant', 'whom', 'you', 'have', 'take', 'into', 'our', 'house', 'come', 'in', 'to', 'make', 'sport', 'of', 'me', 'and', 'when', 'give', 'a', 'loud', 'cry', 'he', 'go', 'run', 'out', 'without', 'his', 'coat', '.']"],
#  ["['and', 'hear', 'his', 'wife', 's', 'account', 'of', 'what', 'his', 'servant', 'have', 'do', 'he', 'become', 'very', 'angry', '.']"],
#  ["['and', 'joseph', 's', 'master', 'take', 'him', 'and', 'put', 'him', 'in', 'prison', 'in', 'the', 'place', 'where', 'the', 'king', 's', 'prisoner', 'be', 'keep', 'in', 'chain', 'and', 'he', 'be', 'there', 'in', 'the', 'prison', 'house', '.']"],
#  ["['but', 'the', 'lord', 'be', 'with', 'joseph', 'and', 'be', 'good', 'to', 'him', 'and', 'make', 'the', 'keeper', 'of', 'the', 'prison', 'his', 'friend', '.']"],
#  ["['and', 'the', 'keeper', 'of', 'the', 'prison', 'put', 'all', 'the', 'prisoner', 'under', 'joseph', 's', 'control', 'and', 'he', 'be', 'responsible', 'for', 'whatever', 'be', 'do', 'there', '.']"],
#  ["['and', 'the', 'keeper', 'of', 'the', 'prison', 'give', 'no', 'attention', 'to', 'anything', 'which', 'be', 'under', 'his', 'care', 'because', 'the', 'lord', 'be', 'with', 'him', 'and', 'the', 'lord', 'make', 'everything', 'he', 'do', 'go', 'well', '.']"],
#  ["['now', 'after', 'these', 'thing', 'the', 'chief', 'servant', 'who', 'have', 'the', 'care', 'of', 'the', 'wine', 'and', 'the', 'chief', 'bread', 'maker', 'in', 'pharaoh', 's', 'house', 'do', 'something', 'against', 'pharaoh', 's', 'order', 'and', 'pharaoh', 'be', 'angry', 'with', 'his', 'two', 'servant', 'with', 'the', 'chief', 'wine', 'servant', 'and', 'the', 'chief', 'bread', 'maker', 'and', 'he', 'put', 'them', 'in', 'prison', 'under', 'the', 'care', 'of', 'the', 'captain', 'of', 'the', 'army', 'in', 'the', 'same', 'prison', 'where', 'joseph', 'himself', 'be', 'shut', 'up', '.']"],
#  ["['and', 'the', 'captain', 'put', 'them', 'in', 'joseph', 's', 'care', 'and', 'he', 'do', 'what', 'be', 'need', 'for', 'them', 'and', 'they', 'be', 'keep', 'in', 'prison', 'for', 'some', 'time', '.']"],
#  ["['then', 'joseph', 'say', 'this', 'be', 'the', 'sense', 'of', 'your', 'dream', 'the', 'three', 'basket', 'be', 'three', 'day', 'after', 'three', 'day', 'pharaoh', 'will', 'take', 'you', 'out', 'of', 'prison', 'hang', 'you', 'on', 'a', 'tree', 'so', 'that', 'your', 'flesh', 'will', 'be', 'food', 'for', 'bird', '.']"],
#  ["['now', 'the', 'third', 'day', 'be', 'pharaoh', 's', 'birthday', 'and', 'he', 'give', 'a', 'feast', 'for', 'all', 'his', 'servant', 'and', 'he', 'give', 'honour', 'to', 'the', 'chief', 'wine', 'servant', 'and', 'the', 'chief', 'bread', 'maker', 'among', 'the', 'others', '.']"],
#  ["['and', 'he', 'put', 'the', 'chief', 'wine', 'servant', 'back', 'in', 'his', 'old', 'place', 'and', 'he', 'give', 'the', 'cup', 'into', 'pharaoh', 's', 'hand', '.']"],
#  ["['but', 'the', 'chief', 'bread', 'maker', 'be', 'put', 'to', 'death', 'by', 'hang', 'a', 'joseph', 'have', 'say', '.']"],
#  ["['but', 'the', 'wine', 'servant', 'do', 'not', 'keep', 'joseph', 'in', 'mind', 'or', 'give', 'a', 'thought', 'to', 'him', '.']"],
#  ["['now', 'after', 'two', 'year', 'have', 'go', 'by', 'pharaoh', 'have', 'a', 'dream', 'and', 'in', 'his', 'dream', 'he', 'be', 'by', 'the', 'side', 'of', 'the', 'nile', 'and', 'out', 'of', 'the', 'nile', 'come', 'seven', 'cow', 'good', 'look', 'and', 'fat', 'and', 'their', 'food', 'be', 'the', 'river', 'grass', '.']"],
#  ["['and', 'after', 'them', 'seven', 'other', 'cow', 'come', 'out', 'of', 'the', 'nile', 'poor', 'look', 'and', 'thin', 'and', 'they', 'be', 'by', 'the', 'side', 'of', 'the', 'other', 'cow', '.']"],
#  ["['and', 'the', 'seven', 'thin', 'cow', 'make', 'a', 'meal', 'of', 'the', 'seven', 'fat', 'cow', '.']"],
#  ["['then', 'pharaoh', 'come', 'out', 'of', 'his', 'sleep', '.']"],
#  ["['but', 'he', 'go', 'to', 'sleep', 'again', 'and', 'have', 'a', 'second', 'dream', 'in', 'which', 'he', 'saw', 'seven', 'head', 'of', 'grain', 'full', 'and', 'good', 'all', 'on', 'one', 'stem', '.']"],
#  ["['and', 'after', 'them', 'come', 'up', 'seven', 'other', 'head', 'thin', 'and', 'waste', 'by', 'the', 'east', 'wind', '.']"],
#  ["['and', 'the', 'seven', 'thin', 'head', 'make', 'a', 'meal', 'of', 'the', 'good', 'head', '.']"],
#  ["['and', 'when', 'pharaoh', 'be', 'awake', 'he', 'saw', 'it', 'be', 'a', 'dream', '.']"],
#  ["['and', 'in', 'the', 'morning', 'his', 'spirit', 'be', 'troubled', 'and', 'he', 'send', 'for', 'all', 'the', 'wise', 'men', 'of', 'egypt', 'and', 'all', 'the', 'holy', 'men', 'and', 'put', 'his', 'dream', 'before', 'them', 'but', 'no', 'one', 'be', 'able', 'to', 'give', 'him', 'the', 'sense', 'of', 'it', '.']"],
#  ["['then', 'the', 'chief', 'wine', 'servant', 'say', 'to', 'pharaoh', 'the', 'memory', 'of', 'my', 'sin', 'come', 'back', 'to', 'me', 'now', 'pharaoh', 'have', 'be', 'angry', 'with', 'his', 'servant', 'and', 'have', 'put', 'me', 'in', 'prison', 'in', 'the', 'house', 'of', 'the', 'captain', 'of', 'the', 'army', 'together', 'with', 'the', 'chief', 'bread', 'maker', 'and', 'we', 'have', 'a', 'dream', 'on', 'the', 'same', 'night', 'the', 'two', 'of', 'u', 'and', 'the', 'dream', 'have', 'a', 'special', 'sense', '.']"],
#  ["['and', 'there', 'be', 'with', 'u', 'a', 'young', 'hebrew', 'the', 'captain', 's', 'servant', 'and', 'when', 'we', 'put', 'our', 'dream', 'before', 'him', 'he', 'give', 'u', 'the', 'sense', 'of', 'them', '.']"],
#  ["['and', 'it', 'come', 'about', 'a', 'he', 'say', 'be', 'put', 'back', 'in', 'my', 'place', 'and', 'the', 'bread', 'maker', 'be', 'put', 'to', 'death', 'by', 'hang', '.']"],
#  ["['then', 'pharaoh', 'sent', 'for', 'joseph', 'and', 'they', 'take', 'him', 'quickly', 'out', 'of', 'prison', 'and', 'when', 'his', 'hair', 'have', 'be', 'cut', 'and', 'his', 'dress', 'change', 'he', 'come', 'before', 'pharaoh', '.']"],
#  ...]

# %%
model.similarity('woman', 'man')
# Out:
# /Users/alexandersteeb/.virtualenvs/ML/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-159-5d0abd574c94> in <module>
# ----> 1 model.similarity('woman', 'man')
#
# /usr/local/lib/python3.7/site-packages/gensim/utils.py in new_func1(*args, **kwargs)
#    1445                     stacklevel=2
#    1446                 )
# -> 1447                 return func(*args, **kwargs)
#    1448
#    1449             return new_func1
#
# /usr/local/lib/python3.7/site-packages/gensim/models/base_any2vec.py in similarity(self, w1, w2)
#    1450
#    1451         """
# -> 1452         return self.wv.similarity(w1, w2)
#    1453
#    1454     @deprecated("Method will be removed in 4.0.0, use self.wv.n_similarity() instead")
#
# /usr/local/lib/python3.7/site-packages/gensim/models/keyedvectors.py in similarity(self, w1, w2)
#     953
#     954         """
# --> 955         return dot(matutils.unitvec(self[w1]), matutils.unitvec(self[w2]))
#     956
#     957     def n_similarity(self, ws1, ws2):
#
# /usr/local/lib/python3.7/site-packages/gensim/models/keyedvectors.py in __getitem__(self, entities)
#     345         if isinstance(entities, string_types):
#     346             # allow calls like trained_model['office'], as a shorthand for trained_model[['office']]
# --> 347             return self.get_vector(entities)
#     348
#     349         return vstack([self.get_vector(entity) for entity in entities])
#
# /usr/local/lib/python3.7/site-packages/gensim/models/keyedvectors.py in get_vector(self, word)
#     463
#     464     def get_vector(self, word):
# --> 465         return self.word_vec(word)
#     466
#     467     def words_closer_than(self, w1, w2):
#
# /usr/local/lib/python3.7/site-packages/gensim/models/keyedvectors.py in word_vec(self, word, use_norm)
#     460             return result
#     461         else:
# --> 462             raise KeyError("word '%s' not in vocabulary" % word)
#     463
#     464     def get_vector(self, word):
#
# KeyError: "word 'woman' not in vocabulary"

# %%
model.wv.evaluate_word_pairs('/tmp/questions-words.txt')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-116-40dae58f9dd9> in <module>
# ----> 1 model.wv.evaluate_word_pairs('/tmp/questions-words.txt')
#
# /usr/local/lib/python3.7/site-packages/gensim/models/keyedvectors.py in evaluate_word_pairs(self, pairs, delimiter, restrict_vocab, case_insensitive, dummy4unknown)
#    1258
#    1259         """
# -> 1260         ok_vocab = [(w, self.vocab[w]) for w in self.index2word[:restrict_vocab]]
#    1261         ok_vocab = {w.upper(): v for w, v in reversed(ok_vocab)} if case_insensitive else dict(ok_vocab)
#    1262
#
# /usr/local/lib/python3.7/site-packages/gensim/models/keyedvectors.py in <listcomp>(.0)
#    1258
#    1259         """
# -> 1260         ok_vocab = [(w, self.vocab[w]) for w in self.index2word[:restrict_vocab]]
#    1261         ok_vocab = {w.upper(): v for w, v in reversed(ok_vocab)} if case_insensitive else dict(ok_vocab)
#    1262
#
# KeyError: Sentence("of david .")

# %%
# Preparation
remove_folder("model")
os.mkdir("model")

# %%
# Open all three text files (full text, old and new testament)

with open("model/text_full.txt", "w") as text_file:
    text_file.write(gen_full_text(df.loc[:,'clean']))
    
with open("model/text_old.txt", "w") as text_file:
    text_file.write(gen_full_text(df.loc[df['testament'] == testaments[0],'clean']))

with open("model/text_new.txt", "w") as text_file:
    text_file.write(gen_full_text(df.loc[df['testament'] == testaments[1],'clean']))

# %%
# Write a function to estimate the word2vec model
def estimate_word2vec(file):
    word2vec.word2phrase(train = file, 
                     output = "model/text-phrases", 
                     min_count = 1,
                     verbose = True)
    word2vec.word2vec("model/text-phrases", "model/text.bin", 
                  size = 100, 
                  min_count = 2,
                  # sample = 1e-5, # Downsample high frequenzy words
                  verbose = True)
    return(word2vec.load('model/text.bin'))

# %%
# Estimate all three models and print the progress

print("Fit full model")
model_full = estimate_word2vec('model/text_full.txt')

print('\n')
print("Fit old testament model")
model_old = estimate_word2vec('model/text_old.txt')

print('\n')
print("Fit new testament model")
model_new = estimate_word2vec('model/text_new.txt')
# Out:
# Fit full model
# Starting training using file model/text_full.txt
# Words processed: 800K     Vocab size: 86K
# Vocab size (unigrams + bigrams): 88325
# Words in train file: 824355
# Starting training using file model/text-phrases
# Vocab size: 4662
# Words in train file: 804947
# Alpha: 0.000002  Progress: 101.23%  Words/thread/sec: 523.74k  021500  Progress: 14.25%  Words/thread/sec: 482.67k  : 0.018697  Progress: 25.47%  Words/thread/sec: 497.66k  read/sec: 506.28k  %  Words/thread/sec: 513.79k  .74k  /sec: 515.37k
#
# Fit old testament model
# Starting training using file model/text_old.txt
# Words processed: 600K     Vocab size: 73K
# Vocab size (unigrams + bigrams): 77128
# Words in train file: 658254
# Starting training using file model/text-phrases
# Vocab size: 4302
# Words in train file: 641955
# Alpha: 0.000002  Progress: 101.17%  Words/thread/sec: 535.96k    Words/thread/sec: 501.30k  ad/sec: 517.52k  read/sec: 526.64k
#
# Fit new testament model
# Starting training using file model/text_new.txt
# Words processed: 100K     Vocab size: 20K
# Vocab size (unigrams + bigrams): 29910
# Words in train file: 166101
# Starting training using file model/text-phrases
# Vocab size: 1644
# Words in train file: 163021
# Alpha: 0.000308  Progress: 100.05%  Words/thread/sec: 571.57k  s/thread/sec: 558.49k

# %% [markdown]
# ### Similarity analysis

# %%
# Set a token for which similar words should be found
token = "god"

# For entire bible text
indexes, metrics = model_full.similar(token)
model_f = model_full.generate_response(indexes, metrics).tolist()

# For old testament
indexes, metrics = model_old.similar(token)
model_o = model_old.generate_response(indexes, metrics).tolist()

# For new testament
indexes, metrics = model_new.similar(token)
model_n = model_new.generate_response(indexes, metrics).tolist()

# Print results
print("Entire bible")
print(model_f)

print("Old testament")
print(model_o)

print("New testament")
print(model_n)
# Out:
# Entire bible
# [('lord', 0.7408725171954492), ('grace', 0.7299075513834203), ('salvation', 0.7272111212221695), ('glory', 0.7237798055977366), ('good_news', 0.6648000964614769), ('praise', 0.6631069053653286), ('righteousness', 0.660377629759928), ('witness', 0.6595646488171046), ('jesus_christ', 0.6586875262161762), ('hope', 0.6527914007087664)]
# Old testament
# [('lord', 0.764647664006624), ('judge', 0.7352550460031766), ('prayer', 0.7315035986906013), ('salvation', 0.7311115688647275), ('praise', 0.7165985003500592), ('blessing', 0.6945130998819522), ('decision', 0.6872686943821908), ('worship', 0.6847994990167701), ('mercy', 0.6838189282973596), ('grace', 0.6635205062132083)]
# New testament
# [('christ', 0.9764036782105054), ('our', 0.9748715258373528), ('law', 0.9619806091756254), ('glory', 0.9603808152014444), ('father', 0.9602605686190153), ('grace', 0.9464390871703742), ('spirit', 0.94280912696844), ('flesh', 0.9423220993821908), ('through', 0.9385527202061164), ('thing', 0.9378628264518118)]

# %%
def plot_word2vec(model):
    plot_df = pd.DataFrame(model)
    xpos = np.arange(len(plot_df))
    performance = plot_df.loc[:, 1]

    plt.bar(xpos, performance, align = 'center')
    plt.ylabel('Proximity')
    plt.title('Token')
    plt.xticks(xpos, plot_df.loc[:, 0])
    plt.xticks(rotation = 90)
    plt.show()

# Entire bible
print("Entire bible - Related words to ->",token)
plot_word2vec(model_f)

# Old testament
print("Entire bible - Related words to ->",token)
plot_word2vec(model_o)

# New
print("New testament - Related words to ->",token)
plot_word2vec(model_n)
# Out:
# Entire bible - Related words to -> god
# Entire bible - Related words to -> god
# New testament - Related words to -> god

# %%
# Another token
token2 = "jesus"

indexes, metrics = model_full.similar(token2)
model_full.generate_response(indexes, metrics).tolist()
# Out:
# [('peter', 0.8628066023248416),
#  ('john', 0.8244989645567827),
#  ('disciple', 0.8099956506585944),
#  ('pharisee', 0.8089430431138334),
#  ('elijah', 0.7839656523333571),
#  ('here', 0.7425929677159822),
#  ('talk', 0.727401351414657),
#  ('baptism', 0.7087372566339405),
#  ('pilate', 0.6932198189247821),
#  ('nazarene_jesus', 0.6873270896325907)]

# %% [markdown]
# ### Analogies
# This allows to construct the king - man + women = queen analogy.

# %%
indexes, metrics = model_full.analogy(pos = ['moses', 'israel'], neg = ['man'])
model_full.generate_response(indexes, metrics).tolist()
# Out:
# [('joshua', 0.46235588139623207),
#  ('meeting', 0.41773450064024464),
#  ('judah', 0.3908085666760517),
#  ('ammon', 0.38704273243564324),
#  ('tent', 0.35577434614004),
#  ('assyria', 0.35247565253431906),
#  ('order', 0.35083674199389936),
#  ('levite', 0.3489137836116196),
#  ('aaron', 0.34476169085601205),
#  ('ark', 0.3426867687137019)]

# %% [markdown]
# ## 6. Sentiment
# In this section we analyse the sentiments of each book of the bible.

# %%
# Calculate the sentiment and group in data frame
df['sentiment'] = df.text.apply(lambda x: TextBlob(str(x)).sentiment.polarity)
sentiment = df[['sentiment','order']].groupby(df['book']).mean()
sentiment = sentiment.sort_values('order', )
#df.reset_index(drop=True, inplace=True)
sentiment = sentiment.iloc[:,[0]]

# %%
# Plot the sentiment
sentiment.plot(kind = 'bar',
                   rot = 'vertical',
                   ylim = (-0.2,0.5),
                   title = 'Average sentiment for each book',
                   figsize = (15, 5), 
                   legend = True, 
                   fontsize = 12,
                   colormap = "viridis"
                  )

# %% [markdown]
# # PART II: Comparison of religious texts
# In this second part of our project we focus not only on the bible but on five different religious books. We obtained the books from [Kaggle](https://www.kaggle.com/tentotheminus9/religious-and-philosophical-texts). The following texts are analysed
# - The King James Bible
# - The Quran
# - The Book Of Mormon
# - The Gospel of Buddha
# - Meditations, by Marcus Aurelius

# %% [markdown]
# ## 1. Import all texts

# %%
# Prepare the paths for importing
path = "texts"
df_books = pd.DataFrame() 

books = os.listdir(path)
books
# Out:
# ['Meditations.txt', 'Mormon.txt', 'Bible.txt', 'Koran.txt', 'Buddha.txt']

# %%
# Prepare the paths to each file
book_list = list()

for book in books:
    book_path = os.path.join(path,book)
    print(book_path)
    with open(book_path, "r", encoding = "utf-8") as infile:
        raw_text = infile.read()
        book_list.append(raw_text)
        #df_books = df_books.append([[book, raw_text, book_path]], ignore_index=True)
# Out:
# texts/Meditations.txt
# texts/Mormon.txt
# texts/Bible.txt
# texts/Koran.txt
# texts/Buddha.txt

# %%
# Open the book and apply the cleaning processes
book_path = os.path.join(path, books[0])
print(book_path)

with open(book_path, "r", encoding="utf-8") as infile:
        raw_text = infile.read()
        meditations = TextBlob(raw_text)        

start = meditations.find("MARCUS AURELIUS ANTONINUS was born on April 26")
end = meditations.find("THIS being neither a critical edition of the text")
meditations = meditations[start:end]

meditations_clean = meditations.raw
meditations_clean = preprocessor(meditations_clean)
meditations_clean = lemmatizer(meditations_clean)
meditations_clean = remove_stopwords(meditations_clean)
# Out:
# texts/Meditations.txt

# %%
# Open the book and apply the cleaning processes
book_path = os.path.join(path,books[1])
print(book_path)

with open(book_path, "r", encoding="utf-8") as infile:
        raw_text = infile.read()
        mormon = TextBlob(raw_text)        

start = mormon.find("THE BOOK OF MORMON")
end = mormon.find("End of the Project Gutenberg EBook of The Book Of Mormon, by Anonymous")
mormon = mormon[start:end]

mormon_clean = mormon.raw
mormon_clean = preprocessor(mormon_clean)
mormon_clean = lemmatizer(mormon_clean)
mormon_clean = remove_stopwords(mormon_clean)
# Out:
# texts/Mormon.txt

# %%
# Open the book and apply the cleaning processes
book_path = os.path.join(path,books[3])
print(book_path)

with open(book_path, "r", encoding="utf-8") as infile:
        raw_text = infile.read()
        koran = TextBlob(raw_text)        

start = koran.find("SURA1 XCVI.-THICK BLOOD, OR CLOTS OF BLOOD [I.]")
end = koran.find("End of The Project Gutenberg Etext of The Koran")
koran = koran[start:end]

koran_clean = koran.raw
koran_clean = preprocessor(koran_clean)
koran_clean = lemmatizer(koran_clean)
koran_clean = remove_stopwords(koran_clean)
# Out:
# texts/Koran.txt

# %%
# Open the book and apply the cleaning processes
book_path = os.path.join(path,books[4])
print(book_path)

with open(book_path, "r", encoding="utf-8") as infile:
        raw_text = infile.read()
        buddha = TextBlob(raw_text)        

start = buddha.find("Rejoice at the glad tidings!")
end = buddha.find("TABLE OF REFERENCE.")
buddha = buddha[start:end]

buddha_clean = buddha.raw
buddha_clean = preprocessor(buddha_clean)
buddha_clean = lemmatizer(buddha_clean)
#buddha_clean = remove_stopwords(buddha_clean)
# Out:
# texts/Buddha.txt

# %%
test = buddha[:100000]

# %%
from textblob import Blobber
from textblob.taggers import NLTKTagger
from textblob.tokenizers import SentenceTokenizer
tb = Blobber(pos_tagger=NLTKTagger(), tokenizer=SentenceTokenizer())

# %%
NLTKTagger?

# %%
test = tb(test.raw)

# %%
test.sentences[1].tokenize(include_punc = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-297-798f0ce2199e> in <module>
# ----> 1 test.sentences[1].tokenize(include_punc = True)
#
# TypeError: tokenize() got an unexpected keyword argument 'include_punc'

# %%
[word for word in test.sentences]
# Out:
# [Sentence("Rejoice at the glad tidings!"),
#  Sentence("The Buddha, our Lord, has found the
#  root of all evil; he has shown us the way of salvation."),
#  Sentence("1
#
#  The Buddha dispels the illusions of our mind and redeems us from
#  the terror of death."),
#  Sentence("2
#
#  The Buddha, our Lord, brings comfort to the weary and
#  sorrow-laden; he restores peace to those who are broken down
#  under the burden of life."),
#  Sentence("He gives courage to the weak when they
#  would fain give up self-reliance and hope."),
#  Sentence("3
#
#  Ye that suffer from the tribulations of life, ye that have to
#  struggle and endure, ye that yearn for a life of truth, rejoice
#  at the glad tidings!"),
#  Sentence("4
#
#  There is balm for the wounded, and there is bread for the hungry."),
#  Sentence("There is water for the thirsty, and there is hope for the
#  despairing."),
#  Sentence("There is light for those in darkness, and there is
#  inexhaustible blessing for the upright."),
#  Sentence("5
#
#  Heal your wounds,")]

# %%
test_s
# Out:
# TextBlob("Rejoice at the glad tidings! The Buddha, our Lord, has found the
# root of all evil; he has shown us the way of salvation.              1
#
# The Buddha dispels the illusions of our mind and redeems us from
# the terror of death.                                                 2
#
# The Buddha, our Lord, brings comfort to the weary and
# sorrow-laden; he restores peace to those who are broken down
# under the burden of life. He gives courage to the weak when they
# would fain give up self-reliance and hope.                           3
#
# Ye that suffer from the tribulations of life, ye that have to
# struggle and endure, ye that yearn for a life of truth, rejoice
# at the glad tidings!                                                 4
#
# There is balm for the wounded, and there is bread for the hungry.
# There is water for the thirsty, and there is hope for the
# despairing. There is light for those in darkness, and there is
# inexhaustible blessing for the upright.                              5
#
# Heal your wounds,")

# %%
from textblob import PatternTagger
blob = TextBlob(buddha, pos_tagger=TextBlob.PatternTagger(include_punc=True))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-246-889ba7e940b0> in <module>
# ----> 1 from textblob import PatternTagger
#       2 blob = TextBlob(buddha, pos_tagger=TextBlob.PatternTagger(include_punc=True))
#
# ImportError: cannot import name 'PatternTagger' from 'textblob' (/Users/alexandersteeb/.virtualenvs/ML/lib/python3.7/site-packages/textblob/__init__.py)

# %%
x = TextBlob(buddha_clean).find("the sun s")
TextBlob(buddha_clean)[x:x+200]
# Out:
# TextBlob("the sun s power through a burning glass cause fire to appear so through the cognizance born of sense and object the mind originates and with it the ego the thought of self whom some brahman teacher ca")

# %%
sentence.tags?

# %%
# We use the bible text from PART I
bible_clean = gen_full_text(df['clean_rm'])

# %% [markdown]
# # 2. LDA analysis

# %%
# Choose the number of topics that should be identified
n_components = 4

# %%
all_texts = pd.DataFrame([['Bible', bible_clean],
                    ['Meditations', meditations_clean],
                    ['Mormon', mormon_clean],
                    ['Koran', koran_clean],
                    ['Buddha', buddha_clean]])

all_texts.columns = ["book", "text"]

# %%
text = [text for text in all_texts['text']]

# %%
count = CountVectorizer(
            min_df = 2,
            max_df = 0.95,
            ngram_range = (1,3)
            )

txt_count = count.fit_transform(text)
txt_count
# Out:
# <5x25316 sparse matrix of type '<class 'numpy.int64'>'
# 	with 57695 stored elements in Compressed Sparse Row format>

# %%
# Fit LDA model
lda = LatentDirichletAllocation(
    n_components = n_components, 
    random_state = 123, 
    learning_method = 'batch',
    max_iter = 50,
    verbose = False,
    evaluate_every = True)

X_topics = lda.fit_transform(txt_count)

lda.components_.shape
# Out:
# (4, 25316)

# %%
# Print most important words of every topic
print("The most important words of our four topics are:")

n_top_words = 5
feature_names = count.get_feature_names()
for topic_idx, topic in enumerate(lda.components_):
    print()
    print("Topic %d:" % (topic_idx + 1))
    print(" ".join([feature_names[i]
    for i in topic.argsort()\
        [:-n_top_words - 1:-1]]))
# Out:
# The most important words of our four topics are:
#
# Topic 1:
# unto shall ye behold pass
#
# Topic 2:
# shall ye thou hath thee
#
# Topic 3:
# israel offering david lord god jesus
#
# Topic 4:
# part king son far child husband good profit see old

# %%
X_topics = pd.DataFrame(X_topics)
X_topics.index = all_texts['book']

# %%
X_topics.plot(kind='bar',
                   stacked=True,
                   rot='vertical',
                   ylim=(0,1),
                   figsize=(15, 5), 
                   legend=True, 
                   fontsize=12,
                   colormap = "viridis"
                  )

# %% [markdown]
# # 3. Sentiment

# %%
all_texts['sentiment'] = all_texts.text.apply(lambda x: TextBlob(str(x)).sentiment.polarity)

sentiment = all_texts[['book','sentiment']].groupby(['book']).mean()

# %%
plt.figure();

ax = sentiment.plot(kind='bar',
                   rot='vertical',
                    title = "Average sentiment per book",
                   ylim=(-0.1,0.25),
                   figsize=(15, 5), 
                   legend=True, 
                   fontsize=12,
                   colormap = "viridis"
                  )

ax.set_xlabel("")

plt.axhline(0, color='k')
